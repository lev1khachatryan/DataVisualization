# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
print('dsdsa')
time.sleep(3)
print('dsdsa')
# Out:
# dsdsa
# dsdsa

# %%
my_url = 'https://en.wikipedia.org/wiki/Armenia'

# %%
response  = requests.get(my_url)

# %%
soup = BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Armenia - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
soup.find('h1') # arajinin kta
# Out:
# <h1 class="firstHeading" id="firstHeading" lang="en">Armenia</h1>

# %%
result = soup.find('h1',{'id':'firstHeading'} ) # bolorin kta

# %%
result.text
# Out:
# 'Armenia'

# %%
result = soup.find('h1',{'class':'firstHeading'} ) # bolorin kta

# %%
result.text
# Out:
# 'Armenia'

# %%
url = 'http://quotes.toscrape.com/'

# %%
result  = requests.get(url)

# soup = BeautifulSoup(result.text)

# %%
result.status_code  # ete 200 uremn ok url enq grel
# Out:
# 200

# %%
soup = BeautifulSoup(result.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
# soup.find_all('span', {'class':'text'})
soup.find('span', {'class':'text'}).text
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
quotes = soup.find_all('span', {'class':'text'})

# %%
quote_text = []
for quot in quotes:
    quote_text.append(quot.text)

# %%
quote_text = [i.text for i in quotes]

# %%
quote_text
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  "“Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”",
#  '“Try not to become a man of success. Rather become a man of value.”',
#  '“It is better to be hated for what you are than to be loved for what you are not.”',
#  "“I have not failed. I've just found 10,000 ways that won't work.”",
#  "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”",
#  '“A day without sunshine is like, you know, night.”']

# %%
soup.find('small', {'class': 'author'}).text
# Out:
# 'Albert Einstein'

# %% [markdown]
# # Wiki

# %%
url = 'https://en.wikipedia.org/wiki/Armenia'
result  = requests.get(url)

soup = BeautifulSoup(result.text)

# %%
urls = soup.find_all('a' )

# %%
len(urls)
# Out:
# 3456

# %% [markdown]
# Hima API-ov anenq

# %%
import wikipedia

# %%
wikipedia.search('Armenia')

# %%
arm = wikipedia.page('Armenia')

# %%
# arm.links

# %%
# arm.content
