# %% [markdown]
# <h1 align="center">Introduction to Plotly</h1>
# <h2 align="center">Part 1: common plots</h2>
#
# This notebook provides a quick introduction to the **common plots** in Plotly Python library mainly based on the examples from the [official documentation](https://plot.ly/python/). It is accompained with the slides that provide the structural overview of plotting with Plotly. Altough examples are build upon official documentation, they are tuned to be more consistent in terms of structure. Students are encouraged to keep this notebook at hand and use it as a cheatsheet when developing a graph together with Documentation. The content is as follows:
#
#
# 1.  [Scatter plot](#scatter)
# 2.  [Line chart](#line)
# 3.  [Pie Chart](#pie)
# 4.  [Bar chart](#bar)
# 5.  [Histogram](#histogram)
# 6.  [Box plot](#box)
# 8.  [Table](#tables)

# %% [markdown]
# # 0) Setup

# %%
#importing necessary libs
import numpy as np
from plotly.offline import plot, iplot
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

#setting up some data for plotting
N=100
random_x = np.random.randn(N)
random_y = np.random.randn(N)
monotone_x = np.linspace(0,1,N)

labels = ['R','Python','SQL','Other']
values = [15,50,15,20]
colors = ['#FEBFB3', '#E1396C', '#96D38C', '#D0F9B1']
values_new = [15,50,5,35]
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <a id = "scatter"><h1>1) Scatter plot</h1></a>

# %% [markdown]
# ## Simple scatter plot

# %%
trace = go.Scatter(x = random_x, y = random_y, mode = 'markers',
                   marker = dict(size = 10, color="rgba(152,0,0,0.5)")
                  )
data = [trace]
figure = dict(data=data)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="6c47ee1d-15e7-4bcd-85f2-af856b35fc69" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6c47ee1d-15e7-4bcd-85f2-af856b35fc69")) {
#                     Plotly.newPlot(
#                         '6c47ee1d-15e7-4bcd-85f2-af856b35fc69',
#                         [{"marker": {"color": "rgba(152,0,0,0.5)", "size": 10}, "mode": "markers", "type": "scatter", "uid": "28648060-beb4-4d5b-a2fb-682954954fc0", "x": [-0.7016443565033947, -1.195355978533315, 0.3407716660322069, 1.405484874396956, 0.294637496135769, -0.7849827466551392, 0.5906424155140104, -0.07775514153392704, -0.07349003838326086, 0.04227559079468894, 1.3991530034027297, 0.0632188615052065, -1.3869344640005494, 0.8356533473090036, -0.01803333133405534, -1.1385063062817908, 1.630773148254457, 1.0303818565599, -0.9325327827027332, -0.3055953841148432, 0.7848462596136205, -1.508806009429385, -0.2847117689488539, -1.0129309851320272, -0.614991415303994, 1.4745183907435366, -1.1752133415854513, -0.36111306113842784, 1.6599893802142576, 0.9849063834092938, -1.9302615239245942, -1.2844684656603953, -1.4303405527729316, 0.6820961774539523, 0.830963644882554, 0.7323601679319917, -0.5710046339780745, 0.4122409663551068, -0.22498022187451763, -0.24672935948628563, -0.08676480395168992, 1.0483273448253185, 0.624022050389334, 1.3658492405893545, 0.5937744801130362, -0.12480482001390393, -1.0213879793491807, 0.6846267258799129, -3.467965724056958, 0.47747956405809283, -1.0712586515204083, 0.14964726537845247, -0.3161794533043256, -0.10415791807896616, -0.6852645802277386, 0.4338492822979888, -1.1718002540126389, 0.3719841965572996, -0.7870398265437168, 1.2133463494085979, -0.6036958540472321, -2.3135233115509086, -1.5345113381622126, -1.153024807749087, -0.6124149191346687, -1.104167717080983, 1.1087370905069027, -0.3071169590512245, 0.15338190948936067, 0.4445863184994437, 0.5057442578450378, -
208344902, -0.5789430655085908, 1.173204375634991, -1.0832757330167215, -1.3526275294250405, -1.7986292409229858, 1.4347058123246126, -0.214079110044441, 2.0617387259869515, 0.4827638055894403, -0.7174266765389488, -1.5289222008362149, -1.502368064707619, -0.49351853334538737, -0.19494948567748777, -0.0565675295784326, -0.6541026872231114, 0.5627973027665296, 0.1570233131633442, -1.6256468201726377, 0.4218419397043233, -1.1344113400302234, 0.7845988825926619, 0.22721027334781485, -0.9994298883919274, 0.13521288612101 ...
#                         {"title": {"text": "Scatter"}, "xaxis": {"showgrid": false, "showline": false, "title": {"text": "X title"}, "zeroline": false}, "yaxis": {"showgrid": false, "showline": false, "title": {"text": "Y title"}, "zeroline": false}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('e5466dda-d93c-4426-a8e4-5c9da5e66ee9');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Multiple scatter plot

# %%
trace_1 = go.Scatter(x = random_x, y = random_y, mode = 'markers', name = "trace 0",
                     marker = dict(size = 10,color="rgba(152,0,0,0.5)")
                    )

trace_2 = go.Scatter(x = random_x-5, y = random_y, mode = 'markers',name = "trace 1",
                     marker = dict(color="rgba(255,165,0,0.5)")
                    )

layout  = dict(title = "Multiple Scatter",
               xaxis = dict(title = "X title",showgrid=False,showline=False,zeroline=False),
               yaxis = dict(title = "Y title",showgrid=False,showline=False,zeroline=False)
              )

data = [trace_1, trace_2]
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="fdca6594-4a4f-44dc-b205-af9b83c0e763" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fdca6594-4a4f-44dc-b205-af9b83c0e763")) {
#                     Plotly.newPlot(
#                         'fdca6594-4a4f-44dc-b205-af9b83c0e763',
#                         [{"marker": {"color": "rgba(152,0,0,0.5)", "size": 10}, "mode": "markers", "name": "trace 0", "type": "scatter", "uid": "5788cec2-d8d9-4c7e-b499-57fc2f1a943e", "x": [-0.7016443565033947, -1.195355978533315, 0.3407716660322069, 1.405484874396956, 0.294637496135769, -0.7849827466551392, 0.5906424155140104, -0.07775514153392704, -0.07349003838326086, 0.04227559079468894, 1.3991530034027297, 0.0632188615052065, -1.3869344640005494, 0.8356533473090036, -0.01803333133405534, -1.1385063062817908, 1.630773148254457, 1.0303818565599, -0.9325327827027332, -0.3055953841148432, 0.7848462596136205, -1.508806009429385, -0.2847117689488539, -1.0129309851320272, -0.614991415303994, 1.4745183907435366, -1.1752133415854513, -0.36111306113842784, 1.6599893802142576, 0.9849063834092938, -1.9302615239245942, -1.2844684656603953, -1.4303405527729316, 0.6820961774539523, 0.830963644882554, 0.7323601679319917, -0.5710046339780745, 0.4122409663551068, -0.22498022187451763, -0.24672935948628563, -0.08676480395168992, 1.0483273448253185, 0.624022050389334, 1.3658492405893545, 0.5937744801130362, -0.12480482001390393, -1.0213879793491807, 0.6846267258799129, -3.467965724056958, 0.47747956405809283, -1.0712586515204083, 0.14964726537845247, -0.3161794533043256, -0.10415791807896616, -0.6852645802277386, 0.4338492822979888, -1.1718002540126389, 0.3719841965572996, -0.7870398265437168, 1.2133463494085979, -0.6036958540472321, -2.3135233115509086, -1.5345113381622126, -1.153024807749087, -0.6124149191346687, -1.104167717080983, 1.1087370905069027, -0.3071169590512245, 0.15338190948936067, 0.4445863184994437, 0.5057442578450378, -0.27494503544651566, -3.2523610020136875, -0.7049268763187041,
"x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [-0.06400437792572465, -0.8676042590965943, 0.11115333878260411, 0.6493805586759023, -1.0416316673978334, 1.4702580446348634, 1.1007249797012577, 0.5203890322616002, -0.2320417462219565, -0.6932432658078872, -2.5650804915322207, 0.0015463584182903662, 0.7501416153878682, -0.7947828139065942, 0.8611772505766939, 0.8636142880876142, -0.6731238945000766, -0.7318523614076964, -0.8599219521433429, -1.1064490290733966, -1.4108929514952457, -0.8667342715502986, -0.37116116330088783, -0.15986641582419742, -0.08591252944998791, -0.12145676070695924, -0.026288433969920488, 0.5803639536826328, 0.2733432233953562, 0.5352732721138003, 0.10655245936398479, 0.5641781349334515, 1.6492073172618915, -0.45259703844181115, -0.08793119449811022, -1.4634721537757795, -0.09652890804113827, 0.8973560697742065, 0.40425975994746527, 0.7617323775652263, 0.7375497408617144, 0.524881821007241, -1.2015388635689086, 0.4858657302618926, 0.006383082772705239, -1.5158694620351623, 0.9467560073291664, 1.615933451372184, 0.015872661629693446, -0.9780106262040044, -0.38396913428197427, 1.7991304850008547, 0.9014009952096754, -1.127138566010302, -1.0178085319409396, 1.163178286016341, -0.2463895357722817, 0.896855320437937, 0.02996299148345865, -1.298148208344902, -0.5789430655085908, 1.173204375634991, -1.0832757330167215, -1.3526275294250405, -1.7986292409229858, 1.4347058123246126, -0.214079110044441, 2.0617387259869515, 0.4827638055894403, -0.7174266765389488, -1.5289222008362149, -1.502368064707619, -0.49351853334538737, -0.19494948567748777, -0.0565675295784326, -0.6541026872231114, 0.5627973027665296, 0.1570233131633442, -1.6256468201726377, 0.4218419397043233, -1.1344113400302234, 0.7845988825926619, 0.22721027334781485, -0.9994298883919274, 0.1352128861210157, 1.4493892714028933, -1.4980529164178273, -0.5196782957852314,  ...
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('1847bf0f-d5b8-4990-8719-6a24393a6e05');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Line with Scatter

# %%
trace_1 = go.Scatter(x = monotone_x,y = random_y,mode = 'markers+lines',name = "Red scatter",
                     marker = dict(size = 10,color="rgba(152,0,0,0.5)")
                    )

trace_2 = go.Scatter(x = random_x,y = random_y-5,mode = 'markers',name = "Yellow scatter",
                     marker = dict(color="rgba(255,165,0,0.5)")
                    )

layout  = dict(title = "Line and Scatter",
               xaxis = dict(title = "X title",showgrid=False,showline=False,zeroline=False),
               yaxis = dict(title = "Y title",showgrid=False,showline=False,zeroline=False)
              )

data = [trace_1, trace_2]
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="0b6c2f64-69f1-450c-962a-047fbd81ebc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0b6c2f64-69f1-450c-962a-047fbd81ebc0")) {
#                     Plotly.newPlot(
#                         '0b6c2f64-69f1-450c-962a-047fbd81ebc0',
#                         [{"marker": {"color": "rgba(152,0,0,0.5)", "size": 10}, "mode": "markers+lines", "name": "Red scatter", "type": "scatter", "uid": "2b531ede-7938-46cb-ac10-2ef10de0f124", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [-0.06400437792572465, -0.8676042590965943, 0.11115333878260411, 0.6493805586759023, -1.0416316673978334, 1.4702580446348634, 1.1007249797012577, 0.5203890322616002, -0.2320417462219565, -0.6932432658078872, -2.5650804915322207, 0.0015463584182903662, 0.7501416153878682, -0.7947828139065942, 0.8611772505766939, 0.8636142880876142, -0.6731238945000766, -0.7318523614076964, -0.8599219521433429, -1.1064490290733966, -1.4108929514952457, -0.8667342715502986, -0.37116116330088783, -0.15986641582419742, -0.08591252944998791, -0.12145676070695924, -0.026288433969920488, 0.5803639536826328, 0.2733432233953562, 0.5352732721138003, 0.10655245936398479, 0.5641781349334515, 1.6492073172618915, -0.45259703844181115, -0.08793119449811022, -1.4634721537757795, -0.09652890804113827, 0.8973560697742065, 0.40425975994746527, 0.7617323775652263, 0.7375497408617144, 0.524881821007241, -1.2015388635689086, 0.4858657302618926, 0.006383082772705239, -1.5158694620351623, 0.9467560073291664, 1.615933451372184, 0.015872661629693446, -0.9780106262040044, -0.38396913428197427, 1.7991304850008547, 0.9014009952096754, -1.127138566010302, -1.0178085319409396, 1.163178286016341, -0.2463895357722817, 0.896855320437937, 0.02996299148345865, -1.298148208344902, -0.5789430655085908, 1.173204375634991, -1.0832757330167215, -1.3526275294250405, -1.7986292409229858, 1.4347058123246126, -0.214079110044441, 2.0617387259869515, 0.4827638055894403, -0.7174266765389488, -1.5289222008362149, -1.502368064707619, -0.49351853334538737, -0.19494948567748777, -0.0565675295784326, -0.6541026872231114, 0.5627973027665296, 0.1570233131633442, -1.6256468201726377, 0.4218419397043233, -1.1344113400302234, 0.7845988825926619, 0.22721027334781485, -0.9994298883919274, 0.1352128861210157, 1.4493892714028933, -1.49805291 ...

# %% [markdown]
# ## Dashed/dotted lines

# %%
trace_1 = go.Scatter(x = monotone_x,y = random_y,mode = 'lines',name = 'dashed line',
                     line = dict(width = 4,color="rgba(152,0,0,0.5)",dash="dash")
                    )

trace_2 = go.Scatter(x = monotone_x,y = random_y-5,mode = 'lines',name = 'dotted line',
                     line = dict(width = 8,color="rgba(255,165,0,0.5)",dash="dot")
                    )

layout  = dict(title = "Line types",
               xaxis = dict(title = "X title",showgrid=False,showline=False,zeroline=False),
               yaxis = dict(title = "Y title",showgrid=False,showline=False,zeroline=False)
              )

data = [trace_1, trace_2]
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="d95e73b9-ced2-4ec0-aed7-9e5c8759940e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d95e73b9-ced2-4ec0-aed7-9e5c8759940e")) {
#                     Plotly.newPlot(
#                         'd95e73b9-ced2-4ec0-aed7-9e5c8759940e',
#                         [{"line": {"color": "rgba(152,0,0,0.5)", "dash": "dash", "width": 4}, "mode": "lines", "name": "dashed line", "type": "scatter", "uid": "30391f94-7566-4e7f-a214-39d63a3e8281", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [-0.06400437792572465, -0.8676042590965943, 0.11115333878260411, 0.6493805586759023, -1.0416316673978334, 1.4702580446348634, 1.1007249797012577, 0.5203890322616002, -0.2320417462219565, -0.6932432658078872, -2.5650804915322207, 0.0015463584182903662, 0.7501416153878682, -0.7947828139065942, 0.8611772505766939, 0.8636142880876142, -0.6731238945000766, -0.7318523614076964, -0.8599219521433429, -1.1064490290733966, -1.4108929514952457, -0.8667342715502986, -0.37116116330088783, -0.15986641582419742, -0.08591252944998791, -0.12145676070695924, -0.026288433969920488, 0.5803639536826328, 0.2733432233953562, 0.5352732721138003, 0.10655245936398479, 0.5641781349334515, 1.6492073172618915, -0.45259703844181115, -0.08793119449811022, -1.4634721537757795, -0.09652890804113827, 0.8973560697742065, 0.40425975994746527, 0.7617323775652263, 0.7375497408617144, 0.524881821007241, -1.2015388635689086, 0.4858657302618926, 0.006383082772705239, -1.5158694620351623, 0.9467560073291664, 1.615933451372184, 0.015872661629693446, -0.9780106262040044, -0.38396913428197427, 1.7991304850008547, 0.9014009952096754, -1.127138566010302, -1.0178085319409396, 1.163178286016341, -0.2463895357722817, 0.896855320437937, 0.02996299148345865, -1.298148208344902, -0.5789430655085908, 1.173204375634991, -1.0832757330167215, -1.3526275294250405, -1.7986292409229858, 1.4347058123246126, -0.214079110044441, 2.0617387259869515, 0.4827638055894403, -0.7174266765389488, -1.5289222008362149, -1.502368064707619, -0.49351853334538737, -0.19494948567748777, -0.0565675295784326, -0.6541026872231114, 0.5627973027665296, 0.1570233131633442, -1.6256468201726377, 0.4218419397043233, -1.1344113400302234, 0.7845988825926619, 0.22721027334781485, -0.9994298883919274, 0.1352128861210157, 1.4493892714028933, -1.49 ...

# %% [markdown]
# <a id = "pie"><h1>3) Pie chart</h1></a>

# %% [markdown]
# ## Simple pie chart

# %%
trace = go.Pie(labels=labels, values=values)

data = [trace]
layout = dict(title="Don't use Pie chart")
figure = dict(data=data, layout=layout)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="eb52e205-e038-4022-a69e-4e1393997e15" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eb52e205-e038-4022-a69e-4e1393997e15")) {
#                     Plotly.newPlot(
#                         'eb52e205-e038-4022-a69e-4e1393997e15',
#                         [{"labels": ["R", "Python", "SQL", "Other"], "type": "pie", "uid": "f7d9ae3a-f51f-4db6-b117-c6f06df05237", "values": [15, 50, 15, 20]}],
#                         {"title": {"text": "Don't use Pie chart"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('eb52e205-e038-4022-a69e-4e1393997e15');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Styled pie chart

# %%
labels = ['HTML/CSS','Python','SQL','Other']
values = [15,50,15,20]
colors = ['#FEBFB3', '#E1396C', '#96D38C', '#D0F9B1']

trace = go.Pie(labels=labels, values=values,hoverinfo='label+percent', textinfo='percent', 
               textfont=dict(size=20),marker=dict(colors=colors)
              )

data = [trace]
layout = dict(title="Still, don't use it")
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="52c24c0a-f415-4a3c-bae9-5e68d1427df1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("52c24c0a-f415-4a3c-bae9-5e68d1427df1")) {
#                     Plotly.newPlot(
#                         '52c24c0a-f415-4a3c-bae9-5e68d1427df1',
#                         [{"hoverinfo": "label+percent", "labels": ["HTML/CSS", "Python", "SQL", "Other"], "marker": {"colors": ["#FEBFB3", "#E1396C", "#96D38C", "#D0F9B1"]}, "textfont": {"size": 20}, "textinfo": "percent", "type": "pie", "uid": "3fbdb65c-5bf7-4470-ac32-2ab4b1102be8", "values": [15, 50, 15, 20]}],
#                         {"title": {"text": "Still, don't use it"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('52c24c0a-f415-4a3c-bae9-5e68d1427df1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Donuts type pie chart

# %%
trace = go.Pie(labels=labels, values=values,hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=20),marker=dict(colors=colors),hole = 0.75
              )

data = [trace]
layout = dict(title="Donuts chart")
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="cc0c4193-1494-4089-adba-ff4f7dfd8799" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cc0c4193-1494-4089-adba-ff4f7dfd8799")) {
#                     Plotly.newPlot(
#                         'cc0c4193-1494-4089-adba-ff4f7dfd8799',
#                         [{"hole": 0.75, "hoverinfo": "label+percent", "labels": ["HTML/CSS", "Python", "SQL", "Other"], "marker": {"colors": ["#FEBFB3", "#E1396C", "#96D38C", "#D0F9B1"]}, "textfont": {"size": 20}, "textinfo": "value", "type": "pie", "uid": "93a564db-e6d2-40e4-8001-c21bcd830b77", "values": [15, 50, 15, 20]}],
#                         {"title": {"text": "Donuts chart"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('cc0c4193-1494-4089-adba-ff4f7dfd8799');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# <a id = "bar"><h1>4) Bar chart</h1></a>

# %% [markdown]
# ## Simple bar chart

# %%
labels
# Out:
# ['HTML/CSS', 'Python', 'SQL', 'Other']

# %%
#trace = go.Bar(x=labels, y=values, orientation="v")
trace = go.Bar(x=values, y=labels, orientation="h")

data = [trace]
layout = dict(title="Use me instead of Pie chart")
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="1cfb3f19-df13-4e56-b7f3-b1092bdc13c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1cfb3f19-df13-4e56-b7f3-b1092bdc13c7")) {
#                     Plotly.newPlot(
#                         '1cfb3f19-df13-4e56-b7f3-b1092bdc13c7',
#                         [{"orientation": "h", "type": "bar", "uid": "9bf39ffe-6e2a-48d4-acac-78f9cdd26dd0", "x": [15, 50, 15, 20], "y": ["HTML/CSS", "Python", "SQL", "Other"]}],
#                         {"title": {"text": "Use me instead of Pie chart"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('1cfb3f19-df13-4e56-b7f3-b1092bdc13c7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Grouped/stacked bar chart

# %%
trace_1 = go.Bar(x=labels, y=values, name="Coverage")
trace_2 = go.Bar(x=labels, y=values_new, name="Difficulty")

#layout = dict(barmode = 'group')
layout = dict(barmode = 'stack')

data = [trace_1,trace_2]
layout=dict(title="Stacked or grouped?")
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="0f453a70-1842-4943-86b6-69f4013aaadf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0f453a70-1842-4943-86b6-69f4013aaadf")) {
#                     Plotly.newPlot(
#                         '0f453a70-1842-4943-86b6-69f4013aaadf',
#                         [{"name": "Coverage", "type": "bar", "uid": "4e8e4ba5-6a0e-4db9-8af7-9008d40de404", "x": ["HTML/CSS", "Python", "SQL", "Other"], "y": [15, 50, 15, 20]}, {"name": "Difficulty", "type": "bar", "uid": "99004fc7-d767-4e2c-bb28-88f5f5c26024", "x": ["HTML/CSS", "Python", "SQL", "Other"], "y": [15, 50, 5, 35]}],
#                         {"title": {"text": "Stacked or grouped?"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('0f453a70-1842-4943-86b6-69f4013aaadf');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# <a id = "histogram"><h1>5) Histogram</h1></a>

# %% [markdown]
# ## Simple vertical histogram

# %%
trace = go.Histogram(x=random_x)
#trace = go.Histogram(y=random_x)

data = [trace]
layout = dict(title="Histogram")
figure = dict(data=data, layout=layout)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="73acc8e6-2f59-4917-8fe4-831e656fee78" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("73acc8e6-2f59-4917-8fe4-831e656fee78")) {
#                     Plotly.newPlot(
#                         '73acc8e6-2f59-4917-8fe4-831e656fee78',
#                         [{"type": "histogram", "uid": "6c87d014-30a5-4a77-b733-a6e713c1f5fd", "x": [-0.7016443565033947, -1.195355978533315, 0.3407716660322069, 1.405484874396956, 0.294637496135769, -0.7849827466551392, 0.5906424155140104, -0.07775514153392704, -0.07349003838326086, 0.04227559079468894, 1.3991530034027297, 0.0632188615052065, -1.3869344640005494, 0.8356533473090036, -0.01803333133405534, -1.1385063062817908, 1.630773148254457, 1.0303818565599, -0.9325327827027332, -0.3055953841148432, 0.7
 1.9034710919588618, 2.8973560697742062, 2.404259759947465, 2.7617323775652265, 2.7375497408617147, 2.524881821007241, 0.7984611364310914, 2.4858657302618927, 2.006383082772705, 0.48413053796483774, 2.9467560073291663, 3.615933451372184, 2.0158726616296936, 1.0219893737959955, 1.6160308657180258, 3.7991304850008545, 2.9014009952096753, 0.8728614339896981, 0.9821914680590604, 3.163178286016341, 1.7536104642277184, 2.896855320437937, 2.0299629914834587, 0.7018517916550979, 1.4210569344914092, 3.173204375634991, 0.9167242669832785, 0.6473724705749595, 0.20137075907701418, 3.4347058123246126, 1.785920889955559, 4.0617387259869515, 2.4827638055894403, 1.2825733234610512, 0.4710777991637851, 0.49763193529238103, 1.5064814666546127, 1.8050505143225122, 1.9434324704215673, 1.3458973127768887, 2.56279730276653, 2.1570233131633443, 0.37435317982736227, 2.4218419397043234, 0.8655886599697766, 2.784598882592662, 2.227210273347815, 1.0005701116080727, 2.135212886121016, 3.449389271402893, 0.5019470835821727, 1.4803217042147687, 1.878328017751247, 2.6488 ...
#                         {"title": {"text": "Any outliers?"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('77da7752-78ef-4442-916a-86801ffbf0ba');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# <a id = "table"><h1>7) Table</h1></a>

# %% [markdown]
# ## Simple table

# %%
table_header = dict(values=['Percentage', 'Letter grade'])
table_cells = dict(values=[ ["90-100", "80-90", "70-80", "60-70"], ["A", "B", "C", "D"] ])
trace = go.Table(header=table_header, cells=table_cells)

data = [trace]
figure = dict(data=data)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="2c736b35-d35c-48ed-ba79-5b490ce8c44f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2c736b35-d35c-48ed-ba79-5b490ce8c44f")) {
#                     Plotly.newPlot(
#                         '2c736b35-d35c-48ed-ba79-5b490ce8c44f',
#                         [{"cells": {"values": [["90-100", "80-90", "70-80", "60-70"], ["A", "B", "C", "D"]]}, "header": {"values": ["Percentage", "Letter grade"]}, "type": "table", "uid": "00cae18c-acbc-4ff4-962b-a880fc03fb89"}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('2c736b35-d35c-48ed-ba79-5b490ce8c44f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Styled table

# %%
table_header = dict(values=['Percentage','Letter grade'],
              align = ['left','center'],
              font = dict(color = 'white', size = 12),
              fill = dict(color='#119DFF')
             )
table_cells = dict(values=[["90-100", "80-90", "70-80", "60-70"],
                     ["A", "B", "C", "D"]],
             align = ['left','center'],
             fill = dict(color=["yellow","white"])
            )
trace = go.Table(header=table_header, cells=table_cells)

data = [trace]
layout = dict(width=500, height=300)
figure = dict(data=data, layout=layout)
iplot(figure)
# Out:
# <div>
#
#
#             <div id="a97086d6-18ca-41d5-9680-ba49f97dabed" class="plotly-graph-div" style="height:300px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a97086d6-18ca-41d5-9680-ba49f97dabed")) {
#                     Plotly.newPlot(
#                         'a97086d6-18ca-41d5-9680-ba49f97dabed',
#                         [{"cells": {"align": ["left", "center"], "fill": {"color": ["yellow", "white"]}, "values": [["90-100", "80-90", "70-80", "60-70"], ["A", "B", "C", "D"]]}, "header": {"align": ["left", "center"], "fill": {"color": "#119DFF"}, "font": {"color": "white", "size": 12}, "values": ["Percentage", "Letter grade"]}, "type": "table", "uid": "9d8ecbfd-cfa3-46af-abf4-0a30e2c2e4b2"}],
#                         {"height": 300, "width": 500},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('a97086d6-18ca-41d5-9680-ba49f97dabed');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
