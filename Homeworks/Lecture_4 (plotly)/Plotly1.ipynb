# %% [markdown]
# <h1 align="center">Introduction to Plotly</h1>
# <h2 align="center">Part 1: common plots</h2>
#
# This notebook provides a quick introduction to the **common plots** in Plotly Python library mainly based on the examples from the [official documentation](https://plot.ly/python/). It is accompained with the slides that provide the structural overview of plotting with Plotly. Altough examples are build upon official documentation, they are tuned to be more consistent in terms of structure. Students are encouraged to keep this notebook at hand and use it as a cheatsheet when developing a graph together with Documentation. The content is as follows:
#
#
# 1.  [Scatter plot](#scatter)
# 2.  [Line chart](#line)
# 3.  [Pie Chart](#pie)
# 4.  [Bar chart](#bar)
# 5.  [Histogram](#histogram)
# 6.  [Box plot](#box)
# 8.  [Table](#tables)

# %% [markdown]
# # 0) Setup

# %%
#importing necessary libs
import numpy as np
from plotly.offline import plot, iplot
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

#setting up some data for plotting
N=100
random_x = np.random.randn(N)
random_y = np.random.randn(N)
monotone_x = np.linspace(0,1,N)

labels = ['R','Python','SQL','Other']
values = [15,50,15,20]
colors = ['#FEBFB3', '#E1396C', '#96D38C', '#D0F9B1']
values_new = [15,50,5,35]
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# <a id = "scatter"><h1>1) Scatter plot</h1></a>

# %% [markdown]
# ## Simple scatter plot

# %%
trace = go.Scatter(x = random_x, y = random_y, mode = 'markers',
                   marker = dict(size = 10, color="rgba(152,0,0,0.5)")
                  )
data = [trace]
figure = dict(data=data)
iplot(figure)
# Out:
# <div id="a274fd71-4b68-4528-88ed-e1fce5574656" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("a274fd71-4b68-4528-88ed-e1fce5574656")) {
#     Plotly.newPlot("a274fd71-4b68-4528-88ed-e1fce5574656", [{"marker": {"color": "rgba(152,0,0,0.5)", "size": 10}, "mode": "markers", "x": [3.387623693016945, -0.2569119864662428, -0.7731720880500268, -1.0025140829487909, 1.3571105490708102, 0.4720929974999036, 2.753510579973256, 1.544250432707348, -0.5590139926907539, -1.2432151871618649, 0.36184468331227687, -0.3043989351768319, -0.667452905318965, 0.41577251507038654, -0.9225169934593693, -0.8683870751571239, -0.11631162810886808, -1.6740984748002925, -0.4534037502170145, -0.21123487379176561, -0.10034156352798353, -0.7394307561270755, -0.6106744478231041, -0.08089292698887862, -0.2917751480795894, -1.4125893934539757, -0.7442151222263059, 2.2861321838797037, -0.8298601035024079, 0.10790331567335482, 0.8337667283413142, -0.4519049299851466, 1.5895493934450655, 0.6012662240204287, -2.4352102307673578, 0.2763289690496227, -0.2310396414805238, 0.2653711142267256, 0.2963289393615167, -0.6462884205298992, 0.3092492850201802, -0.3038095182328637, -0.901378037973245, -0.6788163067833258, 0.09547321757992121, 1.4397523003401016, -0.341167308145439, 1.8666327805737357, 0.9298232470799215, -0.9513350496902863, 0.8106126185701729, 0.8305721017968726, -1.4716261371858606, 0.9134509939911648, -1.1501352116944634, -0.04121070854748879, -0.28740507064051524, 1.3525329185280146, -0.6134034880852725, 0.008317053748162504, 0.20339320010365705, -1.4212700761143278, 0.8651883796499326, 0.27149942046181513, -0.444619221923263, -0.600560388694201, 0.14636802202439853, 0.
, -1.7561721865108113, 0.8125112200651263, 0.2279190132496891, 0.37105323792530825, -1.115291103626485, -0.6110321306991501, 0.007485133483358653, -0.20682778591401674, 0.09943173658517342, 1.6310435042475986, -0.415386391821538, 0.7585795331388556, 1.9784526182200184, -0.4074148276863979, 0.5436080590061166, -0.3644813356690843, 0.40450023312161154, -0.320945408293673, -0.326967530773852, 0.41089569153637956, -0.04147773948258548, 1.1289734527657347, -1.4334043586541472, 0.00813252184489314, 1.4699762595325025, 0.022528285538802213, -1.4361877987988898, 0.17897617587322717, 0.954177124953078, -0.13199078535801442, -0.7516497661861482, 0.05456918837176401, 0.7864358768083966, 0.647589350785857, 0.15916028759865034, -0.7121932867719807, 0.44135188234088857, -0.3015894146319443, -0.8648267924603247, -1.0569600735242324, -1.7826369050087785, 1.1606385702675321, -0.6755723920826922, 0.46960794656558147, 0.6992528564224403, -0.15679214156423832, 1.5491253995548142, 0.5062498875295514, 0.28287370912371496, 0.70293475090 ...
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("4eb2dfc0-7d39-4021-aef1-49ce4235c2cf")) {window._Plotly.Plots.resize(document.getElementById("4eb2dfc0-7d39-4021-aef1-49ce4235c2cf"));};})</script>

# %% [markdown]
# ## Multiple scatter plot

# %%
trace_1 = go.Scatter(x = random_x, y = random_y, mode = 'markers', name = "trace 0",
                     marker = dict(size = 10,color="rgba(152,0,0,0.5)")
                    )

trace_2 = go.Scatter(x = random_x-5, y = random_y, mode = 'markers',name = "trace 1",
                     marker = dict(color="rgba(255,165,0,0.5)")
                    )

layout  = dict(title = "Multiple Scatter",
               xaxis = dict(title = "X title",showgrid=False,showline=False,zeroline=False),
               yaxis = dict(title = "Y title",showgrid=False,showline=False,zeroline=False)
              )

data = [trace_1, trace_2]
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div id="aa149f56-3f84-4ed2-9a68-204ea84e99be" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("aa149f56-3f84-4ed2-9a68-204ea84e99be")) {
#     Plotly.newPlot("aa149f56-3f84-4ed2-9a68-204ea84e99be", [{"marker": {"color": "rgba(152,0,0,0.5)", "size": 10}, "mode": "markers", "name": "trace 0", "x": [3.387623693016945, -0.2569119864662428, -0.7731720880500268, -1.0025140829487909, 1.3571105490708102, 0.4720929974999036, 2.753510579973256, 1.544250432707348, -0.5590139926907539, -1.2432151871618649, 0.36184468331227687, -0.3043989351768319, -0.667452905318965, 0.41577251507038654, -0.9225169934593693, -0.8683870751571239, -0.11631162810886808, -1.6740984748002925, -0.4534037502170145, -0.21123487379176561, -0.10034156352798353, -0.7394307561270755, -0.6106744478231041, -0.08089292698887862, -0.2917751480795894, -1.4125893934539757, -0.7442151222263059, 2.2861321838797037, -0.8298601035024079, 0.10790331567335482, 0.8337667283413142, -0.4519049299851466, 1.5895493934450655, 0.6012662240204287, -2.4352102307673578, 0.2763289690496227, -0.2310396414805238, 0.2653711142267256, 0.2963289393615167, -0.6462884205298992, 0.3092492850201802, -0.3038095182328637, -0.901378037973245, -0.6788163067833258, 0.
style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("76b4c117-2c19-4c87-824c-1ba0532f7934")) {
#     Plotly.newPlot("76b4c117-2c19-4c87-824c-1ba0532f7934", [{"marker": {"color": "rgba(152,0,0,0.5)", "size": 10}, "mode": "lines", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [-1.0755349915910675, -0.07492181205629049, -0.498833169217401, 0.45030952871166785, 0.620790787284809, -1.0057404735819793, 0.7182857653196383, -1.7472594200284968, -0.8294415066005766, 0.28788751728382456, 1.0206971756098013, 2.152849401224836, -1.8402750138213202, 0.5914701428845207, -0.7618705031899511, 1.9543389813191439, 0.3757407235305235, -2.271600472088783, -0.3436556179221955, 0.5344217357762435, 0.5718764419089488, -0.24836108685055774, 1.0660945169521312, 0.036772543661844986, -0.9940050014334685, -0.6301395406944142, -0.2922922973880832, -0.3779582315132887, -0.7899084195119492, -0.6923014078015227, -0.20143895122573177, -0.5294888441354041, -0.590578757659108, -1.3510234445825298, 0.2001693152238967, -1.511911135619705, -0.15819733506148617, -1.7561721865108113, 0.8125112200651263, 0.2279190132496891, 0.37105323792530825, -1.115291103626485, -0.6110321306991501, 0.007485133483358653, -0.20682778591401674, 0.09943173658517342, 1.6310435042475986, -0.415386391821538, 0.7585795331388556, 1.9784526182200184, -0.4074148276863979, 0.5436080590061166, -0.3644813356690843, 0.40450023312161154, -0.320945408293673, -0.326967530773852, 0.41089569153637956, -0.04147773948258548, 1.1289734527657347, -1.4334043586541472, 0.00813252184489314, 1.4699762595325025, 0.022528285538802213, -1.4361877987988898, 0.17897617587322717, 0.954177124953078, -0.13199078535801442, -0.7516497661861482, 0.05456918837176401, 0.7864358768083966, 0.647589350785857, 0.15916028759865034, -0.7121932867719807, 0.44135188234088857, -0.3015894146319443, -0.8648267924603247, -1.0569600735242324, -1.7826369050087785, 1.1606385702675321, -0.6755723920826922, 0.46960794656558147, 0.6992528564224403, -0.15679214156423832, 1.5491253995548142, 0.5062498875295514, 0.28287370912371496, 0.7029347509071043, 0.06259806290062195, -1.2828939994488664, 0.33046879886 ...
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("76b4c117-2c19-4c87-824c-1ba0532f7934")) {window._Plotly.Plots.resize(document.getElementById("76b4c117-2c19-4c87-824c-1ba0532f7934"));};})</script>

# %% [markdown]
# ## Line with Scatter

# %%
trace_1 = go.Scatter(x = monotone_x,y = random_y,mode = 'markers+lines',name = "Red scatter",
                     marker = dict(size = 10,color="rgba(152,0,0,0.5)")
                    )

trace_2 = go.Scatter(x = random_x,y = random_y-5,mode = 'markers',name = "Yellow scatter",
                     marker = dict(color="rgba(255,165,0,0.5)")
                    )

layout  = dict(title = "Line and Scatter",
               xaxis = dict(title = "X title",showgrid=False,showline=False,zeroline=False),
               yaxis = dict(title = "Y title",showgrid=False,showline=False,zeroline=False)
              )

data = [trace_1, trace_2]
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div id="c62d2158-b54d-4c11-8389-2326c2faa64d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("c62d2158-b54d-4c11-8389-2326c2faa64d")) {
#     Plotly.newPlot("c62d2158-b54d-4c11-8389-2326c2faa64d", [{"marker": {"color": "rgba(152,0,0,0.5)", "size": 10}, "mode": "markers+lines", "name": "Red scatter", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [-1.0755349915910675, -0.07492181205629049, -0.498833169217401, 0.45030952871166785, 0.620790787284809, -1.0057404735819793, 0.7182857653196383, -1.7472594200284968, -0.8294415066005766, 0.28788751728382456, 1.0206971756098013, 2.152849401224836, -1.8402750138213202, 0.5914701428845207, -0.7618705031899511, 1.9543389813191439, 0.3757407235305235, -2.271600472088783, -0.3436556179221955, 0.5344217357762435, 0.5718764419089488, -0.24836108685055774, 1.0660945169521312, 0.036772543661844986, -0.9940050014334685, -0.6301395406944142, -0.2922922973880832, -0.3779582315132887, -0.7899084195119492, -0.6923014078015227, -0.20143895122573177, -0.5294888441354041, -0.590578757659108, -1.3510234445825298, 0.2001693152238967, -1.511911135619705, -0.15819733506148617, -1.7561721865108113, 0.8125112200651263, 0.2279190132496891, 0.37105323792530825, -1.115291103626485, -0.6110321306991501, 0.007485133483358653, -0.20682778591401674, 0.09943173658517342, 1.6310435042475986, -0.415386391821538, 0.7585795331388556, 1.9784526182200184, -0.4074148276863979, 0.5436080590061166, -0.3644813356690843, 0.40450023312161154, -0.320945408293673, -0.326967530773852, 0.41089569153637956, -0.04147773948258548, 1.1289734527657347, -1.4334043586541472, 0.00813252184489314, 1.4699762595325025, 0.022528285538802213, -1.4361877987988898, 0.17897617587322717, 0.954177124953078, -0.13199078535801442, -0.7516497661861482, 0.05456918837176401, 0.7864358768083966, 0.647589350785857, 0.15916028759865034, -0.7121932867719807, 0.44135188234088857, -0.3015894146319443, -0.8648267924603247, -1.0569600735242324, -1.7826369050087785, 1.1606385702675321, -0.6755723920826922, 0.46960794656558147, 0.6992528564224403, -0.15679214156423832, 1.5491253995548142, 0.5062498875295514, 0.28287370912371496, 0.7029347509071043, 0.06259806290062195, -1. ...

# %% [markdown]
# ## Dashed/dotted lines

# %%
trace_1 = go.Scatter(x = monotone_x,y = random_y,mode = 'lines',name = 'dashed line',
                     line = dict(width = 4,color="rgba(152,0,0,0.5)",dash="dash")
                    )

trace_2 = go.Scatter(x = monotone_x,y = random_y-5,mode = 'lines',name = 'dotted line',
                     line = dict(width = 8,color="rgba(255,165,0,0.5)",dash="dot")
                    )

layout  = dict(title = "Line types",
               xaxis = dict(title = "X title",showgrid=False,showline=False,zeroline=False),
               yaxis = dict(title = "Y title",showgrid=False,showline=False,zeroline=False)
              )

data = [trace_1, trace_2]
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div id="6514764d-993b-4532-a0e8-3376619e6b71" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("6514764d-993b-4532-a0e8-3376619e6b71")) {
#     Plotly.newPlot("6514764d-993b-4532-a0e8-3376619e6b71", [{"line": {"color": "rgba(152,0,0,0.5)", "dash": "dash", "width": 4}, "mode": "lines", "name": "dashed line", "x": [0.0, 0.010101010101010102, 0.020202020202020204, 0.030303030303030304, 0.04040404040404041, 0.05050505050505051, 0.06060606060606061, 0.07070707070707072, 0.08080808080808081, 0.09090909090909091, 0.10101010101010102, 0.11111111111111112, 0.12121212121212122, 0.13131313131313133, 0.14141414141414144, 0.15151515151515152, 0.16161616161616163, 0.17171717171717174, 0.18181818181818182, 0.19191919191919193, 0.20202020202020204, 0.21212121212121213, 0.22222222222222224, 0.23232323232323235, 0.24242424242424243, 0.25252525252525254, 0.26262626262626265, 0.27272727272727276, 0.2828282828282829, 0.29292929292929293, 0.30303030303030304, 0.31313131313131315, 0.32323232323232326, 0.33333333333333337, 0.3434343434343435, 0.3535353535353536, 0.36363636363636365, 0.37373737373737376, 0.38383838383838387, 0.393939393939394, 0.4040404040404041, 0.4141414141414142, 0.42424242424242425, 0.43434343434343436, 0.4444444444444445, 0.4545454545454546, 0.4646464646464647, 0.4747474747474748, 0.48484848484848486, 0.494949494949495, 0.5050505050505051, 0.5151515151515152, 0.5252525252525253, 0.5353535353535354, 0.5454545454545455, 0.5555555555555556, 0.5656565656565657, 0.5757575757575758, 0.5858585858585859, 0.595959595959596, 0.6060606060606061, 0.6161616161616162, 0.6262626262626263, 0.6363636363636365, 0.6464646464646465, 0.6565656565656566, 0.6666666666666667, 0.6767676767676768, 0.686868686868687, 0.696969696969697, 0.7070707070707072, 0.7171717171717172, 0.7272727272727273, 0.7373737373737375, 0.7474747474747475, 0.7575757575757577, 0.7676767676767677, 0.7777777777777778, 0.787878787878788, 0.797979797979798, 0.8080808080808082, 0.8181818181818182, 0.8282828282828284, 0.8383838383838385, 0.8484848484848485, 0.8585858585858587, 0.8686868686868687, 0.8787878787878789, 0.888888888888889, 0.8989898989898991, 0.9090909090909092, 0.9191919191919192, 0.9292929292929294, 0.9393939393939394, 0.9494949494949496, 0.9595959595959597, 0.9696969696969697, 0.9797979797979799, 0.98989898989899, 1.0], "y": [-1.0755349915910675, -0.07492181205629049, -0.498833169217401, 0.45030952871166785, 0.620790787284809, -1.0057404735819793, 0.7182857653196383, -1.7472594200284968, -0.8294415066005766, 0.28788751728382456, 1.0206971756098013, 2.152849401224836, -1.8402750138213202, 0.5914701428845207, -0.7618705031899511, 1.9543389813191439, 0.3757407235305235, -2.271600472088783, -0.3436556179221955, 0.5344217357762435, 0.5718764419089488, -0.24836108685055774, 1.0660945169521312, 0.036772543661844986, -0.9940050014334685, -0.6301395406944142, -0.2922922973880832, -0.3779582315132887, -0.7899084195119492, -0.6923014078015227, -0.20143895122573177, -0.5294888441354041, -0.590578757659108, -1.3510234445825298, 0.2001693152238967, -1.511911135619705, -0.15819733506148617, -1.7561721865108113, 0.8125112200651263, 0.2279190132496891, 0.37105323792530825, -1.115291103626485, -0.6110321306991501, 0.007485133483358653, -0.20682778591401674, 0.09943173658517342, 1.6310435042475986, -0.415386391821538, 0.7585795331388556, 1.9784526182200184, -0.4074148276863979, 0.5436080590061166, -0.3644813356690843, 0.40450023312161154, -0.320945408293673, -0.326967530773852, 0.41089569153637956, -0.04147773948258548, 1.1289734527657347, -1.4334043586541472, 0.00813252184489314, 1.4699762595325025, 0.022528285538802213, -1.4361877987988898, 0.17897617587322717, 0.954177124953078, -0.13199078535801442, -0.7516497661861482, 0.05456918837176401, 0.7864358768083966, 0.647589350785857, 0.15916028759865034, -0.7121932867719807, 0.44135188234088857, -0.3015894146319443, -0.8648267924603247, -1.0569600735242324, -1.7826369050087785, 1.1606385702675321, -0.6755723920826922, 0.46960794656558147, 0.6992528564224403, -0.15679214156423832, 1.5491253995548142, 0.5062498875295514, 0.28287370912371496, 0.7029347509071043, 0.0625980629006219 ...

# %% [markdown]
# <a id = "pie"><h1>3) Pie chart</h1></a>

# %% [markdown]
# ## Simple pie chart

# %%
trace = go.Pie(labels=labels, values=values)

data = [trace]
layout = dict(title="Don't use Pie chart")
figure = dict(data=data, layout=layout)
iplot(figure)
# Out:
# <div id="cccddcf4-bfd6-4dd9-a43e-c2224a868293" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("cccddcf4-bfd6-4dd9-a43e-c2224a868293")) {
#     Plotly.newPlot("cccddcf4-bfd6-4dd9-a43e-c2224a868293", [{"labels": ["R", "Python", "SQL", "Other"], "values": [15, 50, 15, 20], "type": "pie", "uid": "55428c9e-37c7-42e1-a420-9c6ab28a791a"}], {"title": {"text": "Don't use Pie chart"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("cccddcf4-bfd6-4dd9-a43e-c2224a868293")) {window._Plotly.Plots.resize(document.getElementById("cccddcf4-bfd6-4dd9-a43e-c2224a868293"));};})</script>

# %% [markdown]
# ## Styled pie chart

# %%
labels = ['HTML/CSS','Python','SQL','Other']
values = [15,50,15,20]
colors = ['#FEBFB3', '#E1396C', '#96D38C', '#D0F9B1']

trace = go.Pie(labels=labels, values=values,hoverinfo='label+percent', textinfo='percent', 
               textfont=dict(size=20),marker=dict(colors=colors)
              )

data = [trace]
layout = dict(title="Still, don't use it")
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div id="20155a2a-2a1f-4450-8c5c-b7dec04687a1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("20155a2a-2a1f-4450-8c5c-b7dec04687a1")) {
#     Plotly.newPlot("20155a2a-2a1f-4450-8c5c-b7dec04687a1", [{"hoverinfo": "label+percent", "labels": ["HTML/CSS", "Python", "SQL", "Other"], "marker": {"colors": ["#FEBFB3", "#E1396C", "#96D38C", "#D0F9B1"]}, "textfont": {"size": 20}, "textinfo": "percent", "values": [15, 50, 15, 20], "type": "pie", "uid": "b035a64b-d98b-441f-93be-5cb7c7692cee"}], {"title": {"text": "Still, don't use it"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("20155a2a-2a1f-4450-8c5c-b7dec04687a1")) {window._Plotly.Plots.resize(document.getElementById("20155a2a-2a1f-4450-8c5c-b7dec04687a1"));};})</script>

# %% [markdown]
# ## Donuts type pie chart

# %%
trace = go.Pie(labels=labels, values=values,hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=20),marker=dict(colors=colors),hole = 0.75
              )

data = [trace]
layout = dict(title="Donuts chart")
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div id="c49851e5-ba39-4438-b93c-458bd9001dec" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("c49851e5-ba39-4438-b93c-458bd9001dec")) {
#     Plotly.newPlot("c49851e5-ba39-4438-b93c-458bd9001dec", [{"hole": 0.75, "hoverinfo": "label+percent", "labels": ["HTML/CSS", "Python", "SQL", "Other"], "marker": {"colors": ["#FEBFB3", "#E1396C", "#96D38C", "#D0F9B1"]}, "textfont": {"size": 20}, "textinfo": "value", "values": [15, 50, 15, 20], "type": "pie", "uid": "59349360-8504-4691-bb62-552882776dd7"}], {"title": {"text": "Donuts chart"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("c49851e5-ba39-4438-b93c-458bd9001dec")) {window._Plotly.Plots.resize(document.getElementById("c49851e5-ba39-4438-b93c-458bd9001dec"));};})</script>

# %% [markdown]
# <a id = "bar"><h1>4) Bar chart</h1></a>

# %% [markdown]
# ## Simple bar chart

# %%
#trace = go.Bar(x=labels, y=values, orientation="v")
trace = go.Bar(x=values, y=labels, orientation="h")

data = [trace]
layout = dict(title="Use me instead of Pie chart")
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div id="aaf9391b-81b2-40d9-a78c-f99ef8b52cea" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("aaf9391b-81b2-40d9-a78c-f99ef8b52cea")) {
#     Plotly.newPlot("aaf9391b-81b2-40d9-a78c-f99ef8b52cea", [{"orientation": "h", "x": [15, 50, 15, 20], "y": ["HTML/CSS", "Python", "SQL", "Other"], "type": "bar", "uid": "42c6b7c6-24b3-47fe-bfaa-fd21804745db"}], {"title": {"text": "Use me instead of Pie chart"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("aaf9391b-81b2-40d9-a78c-f99ef8b52cea")) {window._Plotly.Plots.resize(document.getElementById("aaf9391b-81b2-40d9-a78c-f99ef8b52cea"));};})</script>

# %% [markdown]
# ## Grouped/stacked bar chart

# %%
trace_1 = go.Bar(x=labels, y=values, name="Coverage")
trace_2 = go.Bar(x=labels, y=values_new, name="Difficulty")

#layout = dict(barmode = 'group')
layout = dict(barmode = 'stack')

data = [trace_1,trace_2]
layout=dict(title="Stacked or grouped?")
figure = dict(data=data,layout=layout)
iplot(figure)
# Out:
# <div id="2cefbd91-e5d3-4f49-8cb0-fe4f55f81659" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("2cefbd91-e5d3-4f49-8cb0-fe4f55f81659")) {
#     Plotly.newPlot("2cefbd91-e5d3-4f49-8cb0-fe4f55f81659", [{"name": "Coverage", "x": ["HTML/CSS", "Python", "SQL", "Other"], "y": [15, 50, 15, 20], "type": "bar", "uid": "8e8b2b2e-c4b3-4c44-ac35-cdd65c420af0"}, {"name": "Difficulty", "x": ["HTML/CSS", "Python", "SQL", "Other"], "y": [15, 50, 5, 35], "type": "bar", "uid": "815a6832-93b6-4225-9a96-90f94a23ca9a"}], {"title": {"text": "Stacked or grouped?"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("2cefbd91-e5d3-4f49-8cb0-fe4f55f81659")) {window._Plotly.Plots.resize(document.getElementById("2cefbd91-e5d3-4f49-8cb0-fe4f55f81659"));};})</script>

# %% [markdown]
# <a id = "histogram"><h1>5) Histogram</h1></a>

# %% [markdown]
# ## Simple vertical histogram

# %%
trace = go.Histogram(x=random_x)
#trace = go.Histogram(y=random_x)

data = [trace]
layout = dict(title="Histogram")
figure = dict(data=data, layout=layout)
iplot(figure)
# Out:
# <div id="f91edf4e-0a6c-4547-8e4c-c0a00c4e0972" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("f91edf4e-0a6c-4547-8e4c-c0a00c4e0972")) {
#     Plotly.newPlot("f91edf4e-0a6c-4547-8e4c-c0a00c4e0972", [{"x": [3.387623693016945, -0.2569119864662428, -0.7731720880500268, -1.0025140829487909, 1.3571105490708102, 0.4720929974999036, 2.753510579973256, 1.544250432707348, -0.5590139926907539, -1.2432151871618649, 0.36184468331227687, -0.3043989351768319, -0.667452905318965, 0.41577251507038654, -0.9225169934593693, -0.8683870751571239, -0.11631162810886808, -1.6740984748002925, -0.4534037502170145, -0.21123487379176561, -0.10034156352798353, -0.7394307561270755, -0.6106744478231041, -0.08089292698887862, -0.2917751480795894, -1.4125893934539757, -0.7442151222263059, 2.2861321838797037, -0.8298601035024079, 0.10790331567335482, 0.8337667283413142, -0.4519049299851466, 1.5895493934450655, 0.6012662240204287, -2.4352102307673578, 0.2763289690496227, -0.2310396414805238, 0.2653711142267256, 0.2963289393615167, -0.6462884205298992, 0.3092492850201802, -0.3038095182328637, -0.901378037973245, -0.6788163067833258, 0.09547321757992121, 1.4397523003401016, -0.341167308145439, 1.8666327805737357, 0.9298232470799215, -0.9513350496902863, 0.8106126185701729, 0.8305721017968726, -1.4716261371858606, 0.9134509939911648, -1.1501352116944634, -0.04121070854748879, -0.28740507064051524, 1.3525329185280146, -0.6134034880852725, 0.008317053748162504, 0.20339320010365705, -1.4212700761143278, 0.8651883796499326, 0.27149942046181513, -0.444619221923263, -0.600560388694201, 0.14636802202439853, 0.33850518904232596, 1.3387144653665797, 0.1565669620386161, 1.515470170938687, 1.430504836829702, -1.608487341414967, 0.17434332587814924, 
673032469226148, 2.4108956915363797, 1.9585222605174146, 3.1289734527657345, 0.5665956413458528, 2.0081325218448933, 3.4699762595325025, 2.0225282855388023, 0.5638122012011102, 2.178976175873227, 2.954177124953078, 1.8680092146419855, 1.2483502338138517, 2.054569188371764, 2.7864358768083966, 2.647589350785857, 2.15916028759865, 1.2878067132280193, 2.4413518823408884, 1.6984105853680558, 1.1351732075396752, 0.9430399264757676, 0.21736309499122153, 3.1606385702675324, 1.3244276079173078, 2.4696079465655814, 2.69925285642244, 1.8432078584357616, 3.549125399554814, 2.5062498875295516, 2.282873709123715, 2.7029347509071044, 2.062598062900622, 0.7171060005511336, 2.3304687988673445, 1.5169040393060054, 1. ...
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("728296a8-2b2e-4f6a-b404-0234d153d345")) {window._Plotly.Plots.resize(document.getElementById("728296a8-2b2e-4f6a-b404-0234d153d345"));};})</script>

# %% [markdown]
# <a id = "table"><h1>7) Table</h1></a>

# %% [markdown]
# ## Simple table

# %%
table_header = dict(values=['Percentage', 'Letter grade'])
table_cells = dict(values=[ ["90-100", "80-90", "70-80", "60-70"], ["A", "B", "C", "D"] ])
trace = go.Table(header=table_header, cells=table_cells)

data = [trace]
figure = dict(data=data)
iplot(figure)
# Out:
# <div id="f79f21a5-cd7b-413e-b278-5b9dcdc5b292" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("f79f21a5-cd7b-413e-b278-5b9dcdc5b292")) {
#     Plotly.newPlot("f79f21a5-cd7b-413e-b278-5b9dcdc5b292", [{"cells": {"values": [["90-100", "80-90", "70-80", "60-70"], ["A", "B", "C", "D"]]}, "header": {"values": ["Percentage", "Letter grade"]}, "type": "table", "uid": "64487461-074d-42f7-b27a-87d9e087003a"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script><script type="text/javascript">window.addEventListener("resize", function(){if (document.getElementById("f79f21a5-cd7b-413e-b278-5b9dcdc5b292")) {window._Plotly.Plots.resize(document.getElementById("f79f21a5-cd7b-413e-b278-5b9dcdc5b292"));};})</script>

# %% [markdown]
# ## Styled table

# %%
table_header = dict(values=['Percentage','Letter grade'],
              align = ['left','center'],
              font = dict(color = 'white', size = 12),
              fill = dict(color='#119DFF')
             )
table_cells = dict(values=[["90-100", "80-90", "70-80", "60-70"],
                     ["A", "B", "C", "D"]],
             align = ['left','center'],
             fill = dict(color=["yellow","white"])
            )
trace = go.Table(header=table_header, cells=table_cells)

data = [trace]
layout = dict(width=500, height=300)
figure = dict(data=data, layout=layout)
iplot(figure)
# Out:
# <div id="bab74afd-f92b-4cfa-b52c-78faff6cd772" style="height: 300px; width: 500px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("bab74afd-f92b-4cfa-b52c-78faff6cd772")) {
#     Plotly.newPlot("bab74afd-f92b-4cfa-b52c-78faff6cd772", [{"cells": {"align": ["left", "center"], "fill": {"color": ["yellow", "white"]}, "values": [["90-100", "80-90", "70-80", "60-70"], ["A", "B", "C", "D"]]}, "header": {"align": ["left", "center"], "fill": {"color": "#119DFF"}, "font": {"color": "white", "size": 12}, "values": ["Percentage", "Letter grade"]}, "type": "table", "uid": "ba7cfd41-9bf5-44fd-bbd4-faaecbe52a7d"}], {"height": 300, "width": 500}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"});
# }
# });</script>
